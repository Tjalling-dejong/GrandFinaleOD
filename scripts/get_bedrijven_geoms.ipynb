# %%
import geopandas as gpd
from readData import readData

# %%
bedrijven = readData("SQL/bedrijven.sql", geodata=False)
bedrijven
# Out:
# c:\Users\jong\education\Breinstein\GrandFinaleOD\scripts\readData.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn)
#         nic  bedr_Id                                            bedrijf  \
# 0     10723      664                       O-I Netherlands BV (Leerdam)
# 1     11034     1370                                    Dossche Mils NV
# 2     21010      404          Sonneborn Refined Products BV (Amsterdam)
# 3     21011      403                                Rütgers Resins B.V.
# 4     21101      381                     Albemarle Catalysts Company B.
# ..      ...      ...                                                ...
# 107  220243    11677                         RWZI Haarlem-Waarderpolder
# 108  220451     3878  Hoogheemraadschap Hollands Noorderkwartier RWZ...
# ...

# %%
bedrijven = gpd.GeoDataFrame(data=bedrijven, geometry=gpd.points_from_xy(bedrijven["o_Coordinaat"], bedrijven["n_Coordinaat"]))
bedrijven.to_file("bedrijven.geojson")
